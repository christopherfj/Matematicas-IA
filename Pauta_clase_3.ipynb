# %%
from matplotlib import pylab
import seaborn as sns
sns.set_style("dark")
import numpy as np

# %%
#P1
x = np.arange(-1,2,0.1)
y1 = (5-4*x)/4
y2 = (-1+2*x)/4

fig = pylab.figure(1, figsize=(4,4))
pylab.plot(x,y1, 'r')
pylab.plot(x,y2, 'b')
pylab.scatter(1, 1/4, c='k')
pylab.xlabel('x1')
pylab.ylabel('x2')
pylab.grid(True)
pylab.show()

# %%
#P2
x = np.arange(-1,2,0.1)
y1 = 9-3*x
y2 = -7-3*x

fig = pylab.figure(2, figsize=(4,4))
pylab.plot(x,y1, 'r')
pylab.plot(x,y2, 'b')
pylab.fill_between(x, y1, y2, color='g', alpha=0.5)
pylab.xlabel('x1')
pylab.ylabel('x2')
pylab.grid(True)
pylab.show()

# %%
#P3
x = np.arange(-1,2,0.1)
y1 = (2+6*x)/4
y2 = (1+3*x)/2

fig = pylab.figure(3, figsize=(4,4))
pylab.plot(x,y1, 'r')
pylab.plot(x,y2, 'b')
pylab.xlabel('x1')
pylab.ylabel('x2')
pylab.grid(True)
pylab.show()
